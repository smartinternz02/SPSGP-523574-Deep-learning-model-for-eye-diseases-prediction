# %% [markdown]
# ASSIGNMENT 1

# %% [markdown]
# 1. Create pandas dataframe as 'df' with numpy random values (4 features and 4 observations)

# %%
import numpy as np
import pandas as pd

# %%
l=pd.Series(np.random.rand(4))
h=pd.Series(np.random.rand(4))
l1=pd.Series(np.random.rand(4))
h1=pd.Series(np.random.rand(4))
df=pd.DataFrame([l,h,l1,h1])
print(df)
# Out:
#           0         1         2         3
# 0  0.405097  0.143395  0.363841  0.823615
# 1  0.783414  0.877675  0.511673  0.830260
# 2  0.791259  0.474142  0.877404  0.633638
# 3  0.563235  0.436266  0.524004  0.212228

# %% [markdown]
# 2. Rename the task-1 'df' dataframe column names to 'Random Value 1','Random Value 2','Random Value 3'&'Random Value 4'

# %%
l=pd.Series(np.random.rand(4))
h=pd.Series(np.random.rand(4))
l1=pd.Series(np.random.rand(4))
h1=pd.Series(np.random.rand(4))
df=pd.DataFrame([l,h,l1,h1])
df
# Out:
#           0         1         2         3
# 0  0.301968  0.051228  0.258943  0.198681
# 1  0.952878  0.353275  0.761139  0.213494
# 2  0.030388  0.568868  0.132669  0.197336
# 3  0.572922  0.391317  0.559574  0.904305

# %%
df.columns=['Random Value 1','Random Value 2','Random Value 3','Random Value 4']
df
# Out:
#    Random Value 1  Random Value 2  Random Value 3  Random Value 4
# 0        0.301968        0.051228        0.258943        0.198681
# 1        0.952878        0.353275        0.761139        0.213494
# 2        0.030388        0.568868        0.132669        0.197336
# 3        0.572922        0.391317        0.559574        0.904305

# %% [markdown]
# 3. Find the descriptive statistics of the 'df' dataframe

# %%
df.describe()
# Out:
#        Random Value 1  Random Value 2  Random Value 3  Random Value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.464539        0.341172        0.428081        0.378454
# std          0.393759        0.214922        0.285245        0.350644
# min          0.030388        0.051228        0.132669        0.197336
# 25%          0.234073        0.277763        0.227375        0.198345
# 50%          0.437445        0.372296        0.409258        0.206088
# 75%          0.667911        0.435705        0.609965        0.386197
# max          0.952878        0.568868        0.761139        0.904305

# %%
df.describe(include="all")
# Out:
#        Random Value 1  Random Value 2  Random Value 3  Random Value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.464539        0.341172        0.428081        0.378454
# std          0.393759        0.214922        0.285245        0.350644
# min          0.030388        0.051228        0.132669        0.197336
# 25%          0.234073        0.277763        0.227375        0.198345
# 50%          0.437445        0.372296        0.409258        0.206088
# 75%          0.667911        0.435705        0.609965        0.386197
# max          0.952878        0.568868        0.761139        0.904305

# %% [markdown]
# 4. Check for the null values in 'df' and find the datatype of columns

# %%
df.isnull()
# Out:
#    Random Value 1  Random Value 2  Random Value 3  Random Value 4
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %%
df['Random Value 1'].dtype
df['Random Value 2'].dtype
df['Random Value 3'].dtype
df['Random Value 4'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# 5. Display the 'Random Value 2'&'Random Value 3' columns with location menthod and index location method

# %%
df.loc[0:3,'Random Value 2':'Random Value 3']
# Out:
#    Random Value 2  Random Value 3
# 0        0.051228        0.258943
# 1        0.353275        0.761139
# 2        0.568868        0.132669
# 3        0.391317        0.559574

# %%
df.iloc[0:,1:3]
# Out:
#    Random Value 2  Random Value 3
# 0        0.051228        0.258943
# 1        0.353275        0.761139
# 2        0.568868        0.132669
# 3        0.391317        0.559574
